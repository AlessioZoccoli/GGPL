# %% [markdown]
# Assigment 1
# ======

# %% [markdown]
# Produce (and draw) 100 random points within the unit square $[0, 1]^2$

# %%
from pyplasm import *
# Out:
# Evaluating fenvs.py..
# ...fenvs.py imported in 0.007075 seconds

# %%
import numpy as np

# %%
points = np.random.rand(100,2)

# %%
points
# Out:
# array([[ 0.90684814,  0.15700555],
#        [ 0.62675044,  0.65889326],
#        [ 0.65585927,  0.59982853],
#        [ 0.25052281,  0.54326564],
#        [ 0.56436848,  0.61041456],
#        [ 0.58671161,  0.1359974 ],
#        [ 0.80767458,  0.91082302],
#        [ 0.30141015,  0.90963086],
#        [ 0.52228594,  0.10339889],
#        [ 0.35283843,  0.47362965],
#        [ 0.47360154,  0.73372005],
#        [ 0.69465282,  0.57763724],
#        [ 0.09233388,  0.56555722],
#        [ 0.18824155,  0.25276263],
#        [ 0.81868707,  0.65123748],
#        [ 0.56626104,  0.50088356],
#        [ 0.48364176,  0.67432884],
#        [ 0.48279248,  0.46876677],
#        [ 0.06633251,  0.28504181],
#        [ 0.28019504,  0.83039219],
#        [ 0.13288932,  0.19735895],
#        [ 0.40250332,  0.91473737],
#        [ 0.42459857,  0.91905995],
#        [ 0.43159323,  0.55867193],
#        [ 0.74656304,  0.05899967],
#        [ 0.90061921,  0.76850196],
#        [ 0.15637951,  0.10566565],
#        [ 0.92667526,  0.1681756 ],
#        [ 0.90606961,  0.16519809],
#        [ 0.24841272,  0.31821401],
#        [ 0.99646159,  0.51029624],
#        [ 0.5122908 ,  0.41390918],
#        [ 0.94124362,  0.20525489],
#        [ 0.51372249,  0.7701438 ],
#        [ 0.83003812,  0.7683535 ],
#        [ 0.76690828,  0.45146655],
#        [ 0.03549885,  0.00774643],
#        [ 0.18527941,  0.85243825],
#        [ 0.78753547,  0.20127644],
#        [ 0.56287711,  0.25402226],
#        [ 0.03777654,  0.10333764],
#        [ 0.30522873,  0.66310091],
#        [ 0.64977774,  0.99799652],
#        [ 0.18322421,  0.68004506],
#        [ 0.56851213,  0.76975964],
#        [ 0.33858384,  0.48028105],
#        [ 0.52674268,  0.57943821],
#        [ 0.52216739,  0.83513633],
#        [ 0.53464587,  0.9706276 ],
#        [ 0.20831666,  0.1275408 ],
#        [ 0.6651457 ,  0.38203519],
#        [ 0.85531782,  0.30611503],
#        [ 0.85757509,  0.76959908],
#        [ 0.02960027,  0.99241022],
#        [ 0.47138791,  0.62981583],
#        [ 0.79919756,  0.25498817],
#        [ 0.80023073,  0.25468748],
#        [ 0.04164293,  0.62850162],
#        [ 0.31198499,  0.23715193],
#        [ 0.64593862,  0.01937179],
#        [ 0.23195586,  0.48707222],
#        [ 0.76182342,  0.51086374],
#        [ 0.36407612,  0.29028486],
#        [ 0.24529004,  0.30184831],
#        [ 0.45250116,  0.72694796],
#        [ 0.52109382,  0.09737879],
#        [ 0.33896294,  0.14554983],
#        [ 0.15375224,  0.35800537],
#        [ 0.58686504,  0.11277428],
#        [ 0.95574154,  0.92204966],
#        [ 0.75501539,  0.34995059],
#        [ 0.81623512,  0.62667557],
#        [ 0.83070898,  0.87605593],
#        [ 0.73563244,  0.17364376],
#        [ 0.49216384,  0.64197288],
#        [ 0.02066553,  0.93313006],
#        [ 0.37510089,  0.86380487],
#        [ 0.02311526,  0.73265132],
#        [ 0.06700587,  0.20098335],
#        [ 0.04086445,  0.66641282],
#        [ 0.43434902,  0.41122684],
#        [ 0.75314734,  0.07365277],
#        [ 0.41870121,  0.07371859],
#        [ 0.30118719,  0.6517381 ],
#        [ 0.52211692,  0.79985814],
#        [ 0.20680119,  0.7610685 ],
#        [ 0.33005869,  0.86897606],
#        [ 0.30275488,  0.34964025],
#        [ 0.35652283,  0.09681588],
#        [ 0.05356644,  0.11766245],
#        [ 0.79155997,  0.88632069],
#        [ 0.69781207,  0.46451803],
#        [ 0.60760969,  0.97291911],
#        [ 0.91191514,  0.49995811],
#        [ 0.69655   ,  0.78178985],
#        [ 0.6213772 ,  0.1486164 ],
#        [ 0.15026548,  0.65590315],
#        [ 0.52200485,  0.81025903],
#        [ 0.64115024,  0.33073814],
#        [ 0.92007615,  0.33961432]])

# %%
VIEW(STRUCT([MK(p) for p in points]))

# %% [markdown]
# ![100 points](100p2D.png)

# %% [markdown]
# Produce (and draw) 1000 random points within $S_1$, the $1D$ sphere
# (circle) of unit radius centered at the origin $(0, 0)$
