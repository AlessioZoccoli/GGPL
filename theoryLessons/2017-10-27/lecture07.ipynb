# %% [markdown]
# From "Lecture-07b"
# ==================

# %% [markdown]
# ## AA & SUM

# %%
from pyplasm import *
# Out:
# Evaluating fenvs.py..
# ...fenvs.py imported in 0.006263 seconds

# %%
AA(SUM)([[1,2,3],[10,20,30]])
# Out:
# [6, 60]

# %% [markdown]
# ## PROD

# %%
PROD([[1,2,3],[4,5,6]])
# Out:
# 32.0

# %% [markdown]
# ## Product scalar by vector

# %%
SCALARVECTPROD([3,[1,2,3]])
# Out:
# [3, 6, 9]

# %% [markdown]
# ## Innerproduct

# %%
INNERPROD([[1,2,3],[4,5,6]])
# Out:
# 32

# %% [markdown]
# ## Norm of a vector v
# $$VECTORM : R^m \to R^n : v \to \sqrt{\sum\lim_{i=1}^m v^i}$$

# %%
v = [1,2,3]
VECTNORM(v)
# Out:
# 3.7416574954986572

# %% [markdown]
# ## Unit Vector
# $$UNIVECT : R^m \to R^m : v \to \frac{v}{\lvert v \rvert}$$

# %%
UNITVECT(v)
# Out:
# [0.26726123690605164, 0.5345224738121033, 0.8017836809158325]

# %% [markdown]
# # Assigment
# Write a function that adds any two matrices [A], [B] (compatible by sum). Both [A], [B] must belong to the same linear space $R_n^m$

# %%
A = [ [1,2,3], [4,5,6], [7,8,9] ]
B = [ [10,20,30], [40,50,60], [70,80,90] ]

# %%
def MATSUM(args):
    return  AA(AA(SUM)) (AA(TRANS)(TRANS(args)))

# %%
MATSUM([A,B])
# Out:
# [[11, 22, 33], [44, 55, 66], [77, 88, 99]]

# %% [markdown]
# ## N & NN

# %%
N(3)(0)

# %%
N(3)([0,1,2])
# Out:
# [[0, 1, 2], [0, 1, 2], [0, 1, 2]]

# %%
NN(3)([0,1,2])
# Out:
# [0, 1, 2, 0, 1, 2, 0, 1, 2]

# %%
AR([[1,2,3],1])
# Out:
# [1, 2, 3, 1]

# %%
DISTR([[1,2,3],1])

# %% [markdown]
# Vector product w of two $R^3$ vectors

# %%
def VECTPROD(args):
    u,v = args
    w = N(3)(0)

    w[0] = u[1]*v[2] - u[2]*v[1]
    w[1] = u[2]*v[0] - u[0]*v[2]
    w[2] = u[0]*v[1] - u[1]*v[0]
    return w

vp = VECTPROD([[1,0,0], [0,1,0]])
vp
# Out:
# [0, 0, 1]

# %% [markdown]
# # Random points

# %%
from random import random

def randomPoints(m, sx=1, sy=1):
    def point():
        return [random() * sx, random() * sy]
    return [point() for k in range(m)]

# %%
verts = randomPoints(200, 2*PI, 2)
verts
# Out:
# [[0.7234568734350191, 0.3612813523065532],
#  [5.1210192464230655, 1.5030730366419518],
#  [5.506304863331914, 0.7271742100535856],
#  [5.302403829616302, 0.4050604603600576],
#  [2.72701095000889, 1.596253152934575],
#  [4.306620441977314, 1.0826437290832813],
#  [2.2089756514383914, 0.4606112562564755],
#  [2.1848260502377594, 0.3009700104963078],
#  [3.779668516657786, 1.2450193699072727],
#  [0.5130705581067857, 0.9364100548082743],
#  [4.947367012800743, 0.8574292655407647],
#  [2.81778537025759, 0.6945830908042747],
#  [2.7773683294634575, 1.7446270688652623],
#  [2.997085508869484, 1.3903752695700846],
#  [2.6796326895859806, 1.0314635549810443],
#  [5.354921328916796, 0.5564468486222582],
#  [5.034774450288632, 0.510978925349908],
#  [2.686707416512889, 1.3222551505132616],
#  [3.5391156367646857, 0.7023735335453531],
#  [2.2678682416542135, 0.8804923278729895],
#  [3.7183962026862982, 1.1974152498031012],
#  [3.0002688945709624, 0.8643101614155573],
#  [2.8704031835106383, 1.6877955405047949],
#  [0.4379216014894082, 1.2197606788810251],
#  [2.794608709955279, 0.6620716266746993],
#  [2.124874878851581, 0.9878003906296235],
#  [2.5217055635514174, 1.226935850266716],
#  [5.811128626985641, 1.6257749454165562],
#  [4.459237404273074, 1.5705653619067979],
#  [5.799946246993924, 0.5158629259475309],
#  [1.6437285874077432, 1.2448484916124194],
#  [5.6314581396023575, 0.5534513735616826],
#  [5.444989892991149, 0.7905957753730297],
#  [2.2207895396133064, 1.5652516015863296],
#  [2.5272682636440025, 0.6710796050781005],
#  [2.2213564371655616, 0.41536996410393523],
#  [4.098159489977965, 1.4206805505153208],
#  [3.61277202948309, 0.7140803297410969],
#  [5.91800166356373, 1.0003523773688427],
#  [5.00367863370894, 0.6878117288736454],
#  [3.747475750308599, 0.5629054114609786],
#  [1.3779687625303825, 0.6196691416970055],
#  [4.45093727662031, 0.06880589369481616],
#  [1.9555394674131592, 1.5205350982978505],
#  [3.4804851879251633, 1.2425185399095178],
#  [2.9523838386363663, 0.3336110975672133],
#  [1.3010563663767825, 1.2057905954685608],
#  [1.3273739648823624, 1.5517655614689978],
#  [5.8921905195437345, 1.3437265070757103],
#  [1.699413483628251, 1.6513545461304222],
#  [2.65580258035281, 1.5156584375609499],
#  [0.5789392627988221, 0.7618725215687618],
#  [0.07101009331167402, 1.4177215375151266],
#  [6.047781883925616, 0.56356341753211],
#  [5.472527536875287, 0.2977751769663508],
#  [5.499898753478125, 1.5667212594404485],
#  [5.474688927573467, 0.6636826615028435],
#  [4.981177296426098, 1.9892060708976036],
#  [3.4388330574041026, 1.9500815386459927],
#  [1.5527650923654768, 1.6033009805111076],
#  [1.2729346880950472, 0.38213195374120446],
#  [4.83437187736515, 1.896742946623452],
#  [2.214779127438988, 1.8695612943204396],
#  [5.199345195511715, 0.14657233479631104],
#  [3.491496103205909, 0.784796792346452],
#  [0.9379984024088358, 1.8391121801305346],
#  [0.3404183643073444, 1.1170616957258712],
#  [4.772945516124445, 0.5557013162517486],
#  [0.4704455547011106, 1.8778786461918335],
#  [6.229199649883492, 0.5540544655372861],
#  [1.1581221505996233, 1.3144783924241437]]

# %%
obj = MKPOL([verts, AA(LIST)(range(200)), None])
VIEW(obj)

# %% [markdown]
# ![randpoints]
